# %% [markdown]
# # 04.B: Regression trees

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import mylib as my

# %% [markdown]
# Decisions trees are simple yet powerful learning models. They partition the input space into regions: some with single examples, some with more. We have seen classification decision trees in the previous notebook. In this notebook we implement and test a regression decision tree.
#
# This implementation mainly shows two main things:
#
# * how to handle continuous features
# * how to report continuous output (thus the name regression tree)
#
# Because a continuous feature by definition can have too many possible values, these values cannot be used as branches. It cannot just be used for only one node (or split) like we saw with discrete features in the previous decision tree notebook. Instead, it is used multiple times, each using a deferent threshold value.
#
# Our implementation will result in binary decision tree where a feature can be used at multiple split nodes. It is the job of the implementation to find out the "best" threshold values to split at. But "best" based on what? Well, we cannot use the entropy or the gini index here. Instead we will use variance (from statistics) as a measure of impurity.
#
# ### Using variance and variance reduction
#
# Given a set of examples $D$ with a continuous output $y$, we define the variance of $y$ as:
#
# $${\displaystyle \mathrm {V(D)}= var(y) = \frac{1}{|D|} \sum_i^{|D|} (y_i - \bar{y})^2}$$
#
# where $\bar{y}$ is the mean of $y$. We use this variance as a measure of impurity. Zero variance corresponds to pure nodes where all the output values are the same.
#
# Like the situation between entropy and information gain, we are interested here in the reduction in variance caused by splitting the data based a continuous feature $F$ at a threshold value $t$. Such reduction is defined as :
#
# $${\displaystyle \operatorname {Reduction(D, F, t)} =V(D) - [\frac{|D_{F \le t}|}{|D|}V(D_{F \le t}) + \frac{|D_{F > t}|}{|D|}V(D_{F > t}]}$$
#
# Here the best split threshold corresponds to the least variance reduction.
#
# ## Constructing the tree
#
# We simply calculate the variance reduction for all possible threshold values of all continuous features and pick the one with the most variance reduction to be our root node. We then recursively repeat the same calculations on both the left hand side of the threshold and the right hand side of the threshold.
#
# Prediction using this tree involves traversing the tree using the feature values of the unseen example. If a leaf node is reached and there are more than one examples under it, the mean of those examples is return as the prediction outcome.
#
# Here is how such implementation looks:

# %%
class DecisionTreeRegressor:
    def __init__(self, dataset, indices = None, max_depth=None):
        self.ds = dataset
        self.max_depth = max_depth
        self.X = self.ds.inputs
        self.y = self.ds.target.ravel()
        
        if indices is None: 
            indices=np.arange(len(self.y))
            
        self.indices = indices
        self.root = self.Node(self, self.indices, 0)
    
    def output_value(self, y):
        return np.mean(y)
    
    def best_feature_split(self, node, feature_index):
        """
        When called on all the features, it finds the best feature to 
        split by and at what threshold. 
        
        NOTE that: lhs = left hand side and rhs = right hand side
        """
        X, y = self.X[node.indices,feature_index], self.y[node.indices]
        var_d = np.var(y)
        d = len(y)
        
        """Let us sort the feature values"""
        sort_idxs = np.argsort(X)
        sorted_X, sorted_y = X[sort_idxs], y[sort_idxs]

        for i in range(0, node.N - 1):
            xi,yi = sorted_X[i],sorted_y[i]
            
            if i < 2 or xi == sorted_X[i + 1]:
                continue
            
            d_lhs = len(y[np.nonzero(X <= xi )])
            d_rhs = len(y[np.nonzero(X > xi )])
            
            var_lhs = np.var(y[np.nonzero(X <= xi )])
            var_rhs = np.var(y[np.nonzero(X > xi )])
            var_reduction = var_d - ((d_lhs / d) * var_lhs + (d_rhs / d) * var_rhs)            
                            
            if var_reduction > node.split_var_reduction: 
                node.split_feature_index = feature_index
                node.split_var_reduction = var_reduction
                node.split_threshold = xi
                
    def print_tree(self, node=None):
        if node is None: node = self.root
        print(repr(node))
        if node.left: self.print_tree(node.left)
        if node.right: self.print_tree(node.right)


    def predict(self, unseen, node=None):
        if unseen.ndim == 1:
            if node is None:
                node = self.root
                
            if node.is_leaf: return node.value
            node = node.left if unseen[node.split_feature_index] <= node.split_threshold else node.right
            return self.predict(unseen, node)
        else:
            return np.array([self.predict(unseen[i,:]) for i in range(len(unseen))]) 
        
    class Node:
        """
        An internal class representing the nodes of the tree.
        """
        def __init__(self, tree, indices, depth):
            self.tree, self.indices, self.depth = tree, indices, depth            
            self.N, self.M = len(self.indices), self.tree.X.shape[1]
            self.value = self.tree.output_value(self.tree.y[self.indices])
            self.split_feature_index = 0
            self.split_var_reduction = 0
            self.left, self.right = None, None
            
            if tree.max_depth is not None and tree.max_depth == depth:
                return
            
            """
            Find the best split across all features(dimentions) based on the minimum
            variance reduction.
            """
            for feature_index in range(self.M): 
                self.tree.best_feature_split(self, feature_index)
                
            if self.split_var_reduction == 0: 
                return

            feature = self.tree.X[self.indices, self.split_feature_index]

            """Binary branching based on the best found feature and threshold."""
            lhs_indices = np.nonzero(feature <= self.split_threshold)[0]
            rhs_indices = np.nonzero(feature > self.split_threshold)[0]
            
            self.left = self.tree.Node(self.tree, self.indices[lhs_indices], self.depth + 1)
            self.right= self.tree.Node(self.tree, self.indices[rhs_indices], self.depth + 1)

        @property
        def split_name(self): 
            return self.tree.ds.examples.columns[self.split_feature_index]

        @property
        def is_leaf(self): 
            return self.left is None and self.right is None

        @property
        def is_root(self): 
            return self == self.tree.root
           
        def __repr__(self):
            out = f'|{" | " * self.depth}'
            if not self.is_leaf:
                out += f'{self.split_name} (split: {self.split_threshold}), output value: {self.value}'
            else:
                out += f'Leaf (value: {self.value})'
                
            return out

# %% [markdown]
# This implementation has a `max_depth` hyperparameter that be used limit the depth of the tree, which is a measure for preventing the tree from overfitting.
#
# ## An example
#
# We start with the following function:
#
# $$y = sin(3\pi x) + cos (4 \pi x) $$
#
# and we add a small random noise to it.
#
# Let's generate and plot points of this function from the interval $[0, 2]$.

# %%
N = 400
x = np.linspace(0,2,N)
y = np.sin(3*np.pi*x) + np.cos(4*np.pi*x) + np.random.randn(N)*.3

fig = plt.figure(figsize=(16,5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x, y, s=50, facecolors='none', edgecolors='#94a3b8')
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# The goal here is to use a regression tree model to learn this function (capture its ups and downs) and approximate it. Toward that end, let's take this data and split it into training and test datasets.

# %%
ds = my.DataSet(pd.DataFrame({'x': x, 'y': y}), y=True)

train, test = ds.train_test_split(test_portion=.25, shuffle=True)

# %% [markdown]
# We then create a regressioin tree model using training data.

# %%
dt = DecisionTreeRegressor(train)

# %% [markdown]
# Here is the constructed tree of this model:

# %%
dt.print_tree()
# Out:
# |x (split: 1.6591478696741855), output value: -0.03438444539910293
# | | x (split: 1.4035087719298245), output value: 0.14056726820860402
# | |  | x (split: 1.0877192982456139), output value: -0.08070473281773462
# | |  |  | x (split: 0.15037593984962405), output value: 0.18691286992514322
# | |  |  |  | x (split: 0.05012531328320802), output value: 1.1639613469174552
# | |  |  |  |  | x (split: 0.015037593984962405), output value: 1.4034984750556934
# | |  |  |  |  |  | Leaf (value: 1.2653119768612615)
# | |  |  |  |  |  | Leaf (value: 1.5416849732501257)
# | |  |  |  |  | x (split: 0.13032581453634084), output value: 1.0681464956621598
# | |  |  |  |  |  | x (split: 0.08521303258145363), output value: 1.1271127696011496
# | |  |  |  |  |  |  | x (split: 0.08020050125313283), output value: 0.9141792762591208
# | |  |  |  |  |  |  |  | Leaf (value: 0.9443753042808414)
# | |  |  |  |  |  |  |  | Leaf (value: 0.8235911921939588)
# | |  |  |  |  |  |  | x (split: 0.10526315789473684), output value: 1.24878905151088
# | |  |  |  |  |  |  |  | Leaf (value: 1.4024815776603134)
# | |  |  |  |  |  |  |  | x (split: 0.12531328320802004), output value: 1.133519656898805
# | |  |  |  |  |  |  |  |  | Leaf (value: 1.1203836716610975)
# | |  |  |  |  |  |  |  |  | Leaf (value: 1.172927612611928)
# | |  |  |  |  |  | x (split: 0.14536340852130325), output value: 0.9059892423299388
# | |  |  |  |  |  |  | Leaf (value: 0.8059809954707288)
# | |  |  |  |  |  |  | Leaf (value: 1.2060139829075696)
# | |  |  |  | x (split: 0.8120300751879699), output value: 0.03823157994805229
# | |  |  |  |  | x (split: 0.7619047619047619), output value: -0.26802735239151376
# | |  |  |  |  |  | x (split: 0.6215538847117794), output value: -0.29953108713520715
# | |  |  |  |  |  |  | x (split: 0.42606516290726815), output value: -0.2561466646173897
# | |  |  |  |  |  |  |  | x (split: 0.24060150375939848), output value: -0.3673526470374696
# | |  |  |  |  |  |  |  |  | x (split: 0.23057644110275688), output value: -0.09414426669254553
# | |  |  |  |  |  |  |  |  |  | x (split: 0.20551378446115287), output value: -0.1489235057274936
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.20050125313283207), output value: -0.005789187120096819
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.015726880456550258)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 0.0240238928892635)
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.22556390977443608), output value: -0.26343096061341104
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.22055137844611528), output value: -0.22740831943148504
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.23983157108338346)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.19013856447578975)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.407521525341115)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 0.15236230896472078)
# | |  |  |  |  |  |  |  |  | x (split: 0.39598997493734334), output value: -0.45842210715244425
# | |  |  |  |  |  |  |  |  |  | x (split: 0.2907268170426065), output value: -0.48600319729049296
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.2706766917293233), output value: -0.5759573427125486
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.2656641604010025), output value: -0.473955675907828
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.5860501240937778)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.13767233134997853)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.711959565118843)
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.3057644110275689), output value: -0.45601848214980767
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.1716675124842817)
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.3358395989974937), output value: -0.5034103104273954
# | |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.3308270676691729), output value: -0.5883941545070118
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.3208020050125313), output value: -0.47368069499461124
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.39150894866701985)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.5969383144859983)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -1.161961452069015)
# | |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.3508771929824561), output value: -0.4609183883875869
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.3021966049214207)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.38596491228070173), output value: -0.5138256495429757
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.37092731829573933), output value: -0.4835268551987422
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.3659147869674185), output value: -0.523148950040481
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.45611152140070654)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.7242612359598044)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.4306973954097572)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.6198714297477933)
# | |  |  |  |  |  |  |  |  |  | x (split: 0.42105263157894735), output value: -0.3039680023793715
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.41102756892230574), output value: -0.32385969259380715
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.2964600324294529)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.40605867308686994)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.2244012415216287)
# | |  |  |  |  |  |  |  | x (split: 0.44611528822055135), output value: -0.07492210067355594
# | |  |  |  |  |  |  |  |  | Leaf (value: 0.10972119393494391)
# | |  |  |  |  |  |  |  |  | x (split: 0.606516290726817), output value: -0.09800251249961844
# | |  |  |  |  |  |  |  |  |  | x (split: 0.6015037593984962), output value: -0.08252317475706104
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.5764411027568922), output value: -0.09392640790533949
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.5263157894736842), output value: -0.07557747208996596
# | |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.5012531328320802), output value: -0.11663926829301939
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.49122807017543857), output value: -0.09035314952394637
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.48621553884711777), output value: -0.13901027093916302
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.48120300751879697), output value: -0.07626694938892416
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.47619047619047616), output value: -0.14816247011981723
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.47117794486215536), output value: -0.14147433087375708
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.1459268869219976)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.12811666272903557)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.17491502710405785)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 0.28321065426554126)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.5154702002405964)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 0.07994677542931207)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.19549762460023845)
# | |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.5463659147869674), output value: 0.006546120316140919
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 0.030855479958910383)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.017763239326628547)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.20402002279758072)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 0.15694472135678628)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -0.2682752276677497)
# | |  |  |  |  |  |  | x (split: 0.7218045112781954), output value: -0.43954445071543624
# | |  |  |  |  |  |  |  | x (split: 0.7167919799498746), output value: -0.5830996200153574
# | |  |  |  |  |  |  |  |  | x (split: 0.7117794486215538), output value: -0.5530847130430792
# | |  |  |  |  |  |  |  |  |  | x (split: 0.7017543859649122), output value: -0.5968586379597786
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.681704260651629), output value: -0.5570693229448571
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.656641604010025), output value: -0.6253498650151146
# | |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.6466165413533834), output value: -0.5316324254164544
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.6365914786967418), output value: -0.5571781978691246
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.5373745575298091)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.616589118887071)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.42944933560577314)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.8596434640117647)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.39774805811425634)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: -0.7958052130343857)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -0.02779761404268649)
# | |  |  |  |  |  |  |  |  | Leaf (value: -0.9732934106549764)
# | |  |  |  |  |  |  |  | x (split: 0.7418546365914787), output value: -0.18832290444057417
# | |  |  |  |  |  |  |  |  | x (split: 0.7368421052631579), output value: -0.019013041365525896
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -0.12452148891038635)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 0.2975123012690555)
# | |  |  |  |  |  |  |  |  | x (split: 0.7568922305764411), output value: -0.35763276751562245
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -0.4117541947408652)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -0.19526848583989412)
# | |  |  |  |  |  | x (split: 0.8070175438596491), output value: 0.09820356400392283
# | |  |  |  |  |  |  | x (split: 0.7919799498746867), output value: 0.12172149282805056
# | |  |  |  |  |  |  |  | x (split: 0.7869674185463659), output value: 0.040300307972716186
# | |  |  |  |  |  |  |  |  | Leaf (value: 0.09950900296231056)
# | |  |  |  |  |  |  |  |  | Leaf (value: -0.13732577699606693)
# | |  |  |  |  |  |  |  | Leaf (value: 0.230283072635163)
# | |  |  |  |  |  |  | Leaf (value: -0.06642193776497118)
# | |  |  |  |  | x (split: 1.037593984962406), output value: 0.8742356925506514
# | |  |  |  |  |  | x (split: 0.8671679197994987), output value: 1.000406472894592
# | |  |  |  |  |  |  | x (split: 0.8471177944862155), output value: 0.6154750764515056
# | |  |  |  |  |  |  |  | Leaf (value: 0.4853305384051932)
# | |  |  |  |  |  |  |  | Leaf (value: 0.810691883520974)
# | |  |  |  |  |  |  | x (split: 0.9874686716791979), output value: 1.0744317414413393
# | |  |  |  |  |  |  |  | x (split: 0.9624060150375939), output value: 1.2101606843711197
# | |  |  |  |  |  |  |  |  | x (split: 0.9223057644110275), output value: 1.2594660270735407
# | |  |  |  |  |  |  |  |  |  | x (split: 0.9072681704260651), output value: 1.18573110739188
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.8822055137844611), output value: 1.2048557576123178
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.158251578938504)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.2514599362861316)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.147481806951004)
# | |  |  |  |  |  |  |  |  |  | x (split: 0.9523809523809523), output value: 1.4253695963572772
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.4369374833323343)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.3906659354321056)
# | |  |  |  |  |  |  |  |  | x (split: 0.9824561403508771), output value: 1.0819667933448245
# | |  |  |  |  |  |  |  |  |  | x (split: 0.9774436090225563), output value: 0.994371104730499
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 0.9950475120259235)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 0.9923418828442254)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 1.432349547802127)
# | |  |  |  |  |  |  |  | x (split: 1.0325814536340852), output value: 0.7690416198493338
# | |  |  |  |  |  |  |  |  | x (split: 1.0225563909774436), output value: 0.7315192107585405
# | |  |  |  |  |  |  |  |  |  | x (split: 1.012531328320802), output value: 0.812406251495538
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 0.853760415376828)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 0.7503750056736027)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 0.5293016089160472)
# | |  |  |  |  |  |  |  |  | Leaf (value: 1.0316984834848864)
# | |  |  |  |  |  | x (split: 1.06265664160401), output value: 0.22235332744029165
# | |  |  |  |  |  |  | x (split: 1.0576441102756893), output value: 0.26425196334272905
# | |  |  |  |  |  |  |  | x (split: 1.0526315789473684), output value: 0.19496285326748086
# | |  |  |  |  |  |  |  |  | Leaf (value: 0.26135067524326955)
# | |  |  |  |  |  |  |  |  | Leaf (value: -0.00420061265988525)
# | |  |  |  |  |  |  |  | Leaf (value: 0.5414084036437218)
# | |  |  |  |  |  |  | Leaf (value: 0.012860147928104748)
# | |  |  | x (split: 1.3082706766917291), output value: -0.9671880419035176
# | |  |  |  | x (split: 1.117794486215539), output value: -1.324673564219407
# | |  |  |  |  | x (split: 1.1027568922305764), output value: -0.6474310122335397
# | |  |  |  |  |  | Leaf (value: -0.5550650257679854)
# | |  |  |  |  |  | Leaf (value: -0.7397969986990941)
# | |  |  |  |  | x (split: 1.2932330827067668), output value: -1.4647927129061382
# | |  |  |  |  |  | x (split: 1.1528822055137844), output value: -1.5191482044361688
# | |  |  |  |  |  |  | x (split: 1.1428571428571428), output value: -1.220787123524543
# | |  |  |  |  |  |  |  | x (split: 1.137844611528822), output value: -1.1373777712002775
# | |  |  |  |  |  |  |  |  | Leaf (value: -1.1523644644029896)
# | |  |  |  |  |  |  |  |  | Leaf (value: -1.0924176915921409)
# | |  |  |  |  |  |  |  | Leaf (value: -1.3876058281730743)
# | |  |  |  |  |  |  | x (split: 1.2731829573934836), output value: -1.604394227553776
# | |  |  |  |  |  |  |  | x (split: 1.1779448621553885), output value: -1.6573972492808986
# | |  |  |  |  |  |  |  |  | x (split: 1.1679197994987467), output value: -1.4832644102704216
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -1.472639170673867)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -1.5151401290600852)
# | |  |  |  |  |  |  |  |  | x (split: 1.2030075187969924), output value: -1.7071494889981778
# | |  |  |  |  |  |  |  |  |  | x (split: 1.1979949874686717), output value: -1.8489916516655567
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: -1.8704756893471401)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: -1.7845395386208063)
# | |  |  |  |  |  |  |  |  |  | x (split: 1.2330827067669172), output value: -1.6504126239312256
# | |  |  |  |  |  |  |  |  |  |  | x (split: 1.2230576441102756), output value: -1.580586575591108
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 1.218045112781955), output value: -1.6083702604622223
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -1.56993703731236)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -1.7236699299118092)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -1.4694518361066498)
# | |  |  |  |  |  |  |  |  |  |  | x (split: 1.2531328320802004), output value: -1.7202386722713439
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -1.8378808394809958)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: -1.5437754214568657)
# | |  |  |  |  |  |  |  | Leaf (value: -1.2863760971910414)
# | |  |  |  |  |  | Leaf (value: -0.7309935772507266)
# | |  |  |  | x (split: 1.3684210526315788), output value: -0.0047270202838151
# | |  |  |  |  | x (split: 1.3283208020050123), output value: -0.3798280377736986
# | |  |  |  |  |  | Leaf (value: -0.531031520406009)
# | |  |  |  |  |  | x (split: 1.363408521303258), output value: -0.2664254257994658
# | |  |  |  |  |  |  | Leaf (value: -0.2507443633482536)
# | |  |  |  |  |  |  | Leaf (value: -0.31346861315310237)
# | |  |  |  |  | x (split: 1.3834586466165413), output value: 0.43289083345438223
# | |  |  |  |  |  | Leaf (value: 0.34908544701628763)
# | |  |  |  |  |  | Leaf (value: 0.5166962198924769)
# | |  | x (split: 1.5839598997493733), output value: 1.3150109659637859
# | |  |  | x (split: 1.4736842105263157), output value: 1.6991679812339258
# | |  |  |  | x (split: 1.4285714285714284), output value: 1.4565323206049678
# | |  |  |  |  | Leaf (value: 1.19794290816697)
# | |  |  |  |  | x (split: 1.4686716791979948), output value: 1.5535033502692173
# | |  |  |  |  |  | x (split: 1.4536340852130325), output value: 1.6152011507948127
# | |  |  |  |  |  |  | x (split: 1.4486215538847116), output value: 1.6480538570450718
# | |  |  |  |  |  |  |  | x (split: 1.443609022556391), output value: 1.5949485235464849
# | |  |  |  |  |  |  |  |  | Leaf (value: 1.5644521433209466)
# | |  |  |  |  |  |  |  |  | Leaf (value: 1.686437664223099)
# | |  |  |  |  |  |  |  | Leaf (value: 1.8604751910394197)
# | |  |  |  |  |  |  | Leaf (value: 1.5330693851691648)
# | |  |  |  |  |  | Leaf (value: 1.1216187465900487)
# | |  |  |  | x (split: 1.543859649122807), output value: 1.8561675263467812
# | |  |  |  |  | x (split: 1.518796992481203), output value: 2.078624807967432
# | |  |  |  |  |  | x (split: 1.5087719298245612), output value: 2.1679966917055835
# | |  |  |  |  |  |  | x (split: 1.493734335839599), output value: 2.1324651561863597
# | |  |  |  |  |  |  |  | Leaf (value: 2.2244464145667515)
# | |  |  |  |  |  |  |  | Leaf (value: 1.994493268615772)
# | |  |  |  |  |  |  | Leaf (value: 2.256825530503643)
# | |  |  |  |  |  | x (split: 1.5338345864661653), output value: 1.9222240114256661
# | |  |  |  |  |  |  | Leaf (value: 1.9022233491308327)
# | |  |  |  |  |  |  | Leaf (value: 1.9822259983101662)
# | |  |  |  |  | x (split: 1.5689223057644108), output value: 1.4483291767089217
# | |  |  |  |  |  | Leaf (value: 1.388976381564831)
# | |  |  |  |  |  | Leaf (value: 1.5076819718530121)
# | |  |  | x (split: 1.6240601503759398), output value: 0.33715674527615797
# | |  |  |  | x (split: 1.6090225563909772), output value: 0.7655805120491538
# | |  |  |  |  | x (split: 1.5989974937343359), output value: 0.8447734600711805
# | |  |  |  |  |  | Leaf (value: 0.82170251904145)
# | |  |  |  |  |  | Leaf (value: 0.9139862831603716)
# | |  |  |  |  | Leaf (value: 0.6071946160051007)
# | |  |  |  | x (split: 1.644110275689223), output value: -0.1769517748514371
# | |  |  |  |  | Leaf (value: -0.11165596703298601)
# | |  |  |  |  | Leaf (value: -0.2748954865791138)
# | | x (split: 1.9047619047619047), output value: -0.831386696278657
# | |  | x (split: 1.8596491228070176), output value: -1.3327733597471298
# | |  |  | x (split: 1.6842105263157894), output value: -1.4691668356443341
# | |  |  |  | x (split: 1.6741854636591478), output value: -0.7170439449143571
# | |  |  |  |  | Leaf (value: -0.5964064015089233)
# | |  |  |  |  | Leaf (value: -1.0789565751306587)
# | |  |  |  | x (split: 1.7393483709273183), output value: -1.576612962891474
# | |  |  |  |  | x (split: 1.7142857142857142), output value: -1.3318335042205556
# | |  |  |  |  |  | Leaf (value: -1.4171974029198664)
# | |  |  |  |  |  | x (split: 1.7293233082706765), output value: -1.280615165000969
# | |  |  |  |  |  |  | Leaf (value: -1.2123854765697928)
# | |  |  |  |  |  |  | Leaf (value: -1.382959697647733)
# | |  |  |  |  | x (split: 1.8395989974937343), output value: -1.674524746359841
# | |  |  |  |  |  | x (split: 1.789473684210526), output value: -1.7684390232894789
# | |  |  |  |  |  |  | x (split: 1.7844611528822054), output value: -1.7143522209115594
# | |  |  |  |  |  |  |  | x (split: 1.7593984962406015), output value: -1.7936956433550617
# | |  |  |  |  |  |  |  |  | x (split: 1.7543859649122806), output value: -1.7202759744139258
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -1.818588865280769)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -1.4253373018133964)
# | |  |  |  |  |  |  |  |  | x (split: 1.7794486215538847), output value: -1.8671153122961979
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -1.9250594277181368)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: -1.6932829660303805)
# | |  |  |  |  |  |  |  | Leaf (value: -1.0796048413635395)
# | |  |  |  |  |  |  | x (split: 1.8145363408521302), output value: -1.8379791977753757
# | |  |  |  |  |  |  |  | Leaf (value: -2.044487779249182)
# | |  |  |  |  |  |  |  | x (split: 1.8345864661654134), output value: -1.683097761670021
# | |  |  |  |  |  |  |  |  | Leaf (value: -1.6653566697119924)
# | |  |  |  |  |  |  |  |  | Leaf (value: -1.7363210375441067)
# | |  |  |  |  |  | x (split: 1.8546365914786966), output value: -1.2988676386412896
# | |  |  |  |  |  |  | Leaf (value: -1.3367134873122026)
# | |  |  |  |  |  |  | Leaf (value: -1.1853300926285515)
# | |  |  | x (split: 1.894736842105263), output value: -0.7092603270741945
# | |  |  |  | x (split: 1.8897243107769421), output value: -0.6699232519506767
# | |  |  |  |  | x (split: 1.8796992481203008), output value: -0.7131487175684019
# | |  |  |  |  |  | Leaf (value: -0.7150680739279188)
# | |  |  |  |  |  | Leaf (value: -0.7073906484898511)
# | |  |  |  |  | Leaf (value: -0.4970213894797765)
# | |  |  |  | Leaf (value: -0.8076030148829887)
# | |  | x (split: 1.969924812030075), output value: 0.4722186287393721
# | |  |  | x (split: 1.9197994987468672), output value: 0.21033896899910737
# | |  |  |  | Leaf (value: -0.18254082967098503)
# | |  |  |  | x (split: 1.9398496240601504), output value: 0.378716025572004
# | |  |  |  |  | Leaf (value: 0.31215116233908)
# | |  |  |  |  | x (split: 1.9598997493734336), output value: 0.42863967299669703
# | |  |  |  |  |  | Leaf (value: 0.4060218899051479)
# | |  |  |  |  |  | Leaf (value: 0.4964930222713442)
# | |  |  | x (split: 1.9899749373433582), output value: 0.9959779482199018
# | |  |  |  | Leaf (value: 0.9531735426592619)
# | |  |  |  | Leaf (value: 1.0601845565608614)

# %% [markdown]
# As you can see, this is a large, deep, and complex tree. Let's see how this model performs on both the training test datasets.

# %%
fig = plt.figure(figsize=(16,5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x, y, s=50, facecolors='none', edgecolors='#94a3b8', label="original data")

# Using training data
ax.scatter(train.inputs, dt.predict(train.inputs), color='#0ea5e9', label="predicted-train")

# Using testing data
ax.scatter(test.inputs, dt.predict(test.inputs), color='#f43f5e', label="predicted-test")

ax.set_xlabel('x')
ax.set_ylabel('y')
plt.legend()

# %% [markdown]
# You can see how well this model does in approximating this function. The predicted training outcomes are very close to the actual ones which is understandable since that is the data the model was trained on. The predicted test outcomes are close too.
#
# Because of the complexity of this tree, it may be overfitting. One way of countering overfitting in decision trees is to limit the depth of the tree to a certain `max_depth` value. To see how that works, need a new measure for training and testing errors. We'll use an L2 loss defined as:
# $$ L2\ loss = \frac{1}{N} \sum_{i=1}^N (actual - predicted)^2$$

# %%
def l2_loss(actual, predicted):
    return np.sum((actual - predicted)**2) / len(actual)

# %% [markdown]
# We not plot the training and testing errors side by side for a range of `max_depth` values: 1 to 20.

# %%
depths = range(1,21)
train_errors = []
test_errors = []
for d in depths:
    dt = DecisionTreeRegressor(train, max_depth=d)
    train_errors.append(l2_loss(train.y.flatten(), dt.predict(train.inputs)))
    test_errors.append(l2_loss(test.y.flatten(), dt.predict(test.inputs)))
    
# Plotting the learning curves
fig = plt.figure(figsize=(16,5))
ax = fig.add_subplot(1, 1, 1)
ax.plot(depths, train_errors, label="Training") 
ax.plot(depths, test_errors, label="Testing") 
ax.set_xticks(np.arange(1, 21, 1))
ax.set_xlabel('max depth')
ax.set_ylabel('L2 loss')
plt.legend()

# %% [markdown]
# From the above plot, the best test results happen when `max_depth` around 6 or 7 (because of the added random noise, these numbers might change slightly from one run to another). Let's create a model with this value

# %%
dt = DecisionTreeRegressor(train, max_depth=6)

# %% [markdown]
# Here is the constructed tree:

# %%
dt.print_tree()
# Out:
# |x (split: 1.6591478696741855), output value: -0.03438444539910293
# | | x (split: 1.4035087719298245), output value: 0.14056726820860402
# | |  | x (split: 1.0877192982456139), output value: -0.08070473281773462
# | |  |  | x (split: 0.15037593984962405), output value: 0.18691286992514322
# | |  |  |  | x (split: 0.05012531328320802), output value: 1.1639613469174552
# | |  |  |  |  | x (split: 0.015037593984962405), output value: 1.4034984750556934
# | |  |  |  |  |  | Leaf (value: 1.2653119768612615)
# | |  |  |  |  |  | Leaf (value: 1.5416849732501257)
# | |  |  |  |  | x (split: 0.13032581453634084), output value: 1.0681464956621598
# | |  |  |  |  |  | Leaf (value: 1.1271127696011496)
# | |  |  |  |  |  | Leaf (value: 0.9059892423299388)
# | |  |  |  | x (split: 0.8120300751879699), output value: 0.03823157994805229
# | |  |  |  |  | x (split: 0.7619047619047619), output value: -0.26802735239151376
# | |  |  |  |  |  | Leaf (value: -0.29953108713520715)
# | |  |  |  |  |  | Leaf (value: 0.09820356400392283)
# | |  |  |  |  | x (split: 1.037593984962406), output value: 0.8742356925506514
# | |  |  |  |  |  | Leaf (value: 1.000406472894592)
# | |  |  |  |  |  | Leaf (value: 0.22235332744029165)
# | |  |  | x (split: 1.3082706766917291), output value: -0.9671880419035176
# | |  |  |  | x (split: 1.117794486215539), output value: -1.324673564219407
# | |  |  |  |  | x (split: 1.1027568922305764), output value: -0.6474310122335397
# | |  |  |  |  |  | Leaf (value: -0.5550650257679854)
# | |  |  |  |  |  | Leaf (value: -0.7397969986990941)
# | |  |  |  |  | x (split: 1.2932330827067668), output value: -1.4647927129061382
# | |  |  |  |  |  | Leaf (value: -1.5191482044361688)
# | |  |  |  |  |  | Leaf (value: -0.7309935772507266)
# | |  |  |  | x (split: 1.3684210526315788), output value: -0.0047270202838151
# | |  |  |  |  | x (split: 1.3283208020050123), output value: -0.3798280377736986
# | |  |  |  |  |  | Leaf (value: -0.531031520406009)
# | |  |  |  |  |  | Leaf (value: -0.2664254257994658)
# | |  |  |  |  | x (split: 1.3834586466165413), output value: 0.43289083345438223
# | |  |  |  |  |  | Leaf (value: 0.34908544701628763)
# | |  |  |  |  |  | Leaf (value: 0.5166962198924769)
# | |  | x (split: 1.5839598997493733), output value: 1.3150109659637859
# | |  |  | x (split: 1.4736842105263157), output value: 1.6991679812339258
# | |  |  |  | x (split: 1.4285714285714284), output value: 1.4565323206049678
# | |  |  |  |  | Leaf (value: 1.19794290816697)
# | |  |  |  |  | x (split: 1.4686716791979948), output value: 1.5535033502692173
# | |  |  |  |  |  | Leaf (value: 1.6152011507948127)
# | |  |  |  |  |  | Leaf (value: 1.1216187465900487)
# | |  |  |  | x (split: 1.543859649122807), output value: 1.8561675263467812
# | |  |  |  |  | x (split: 1.518796992481203), output value: 2.078624807967432
# | |  |  |  |  |  | Leaf (value: 2.1679966917055835)
# | |  |  |  |  |  | Leaf (value: 1.9222240114256661)
# | |  |  |  |  | x (split: 1.5689223057644108), output value: 1.4483291767089217
# | |  |  |  |  |  | Leaf (value: 1.388976381564831)
# | |  |  |  |  |  | Leaf (value: 1.5076819718530121)
# | |  |  | x (split: 1.6240601503759398), output value: 0.33715674527615797
# | |  |  |  | x (split: 1.6090225563909772), output value: 0.7655805120491538
# | |  |  |  |  | x (split: 1.5989974937343359), output value: 0.8447734600711805
# | |  |  |  |  |  | Leaf (value: 0.82170251904145)
# | |  |  |  |  |  | Leaf (value: 0.9139862831603716)
# | |  |  |  |  | Leaf (value: 0.6071946160051007)
# | |  |  |  | x (split: 1.644110275689223), output value: -0.1769517748514371
# | |  |  |  |  | Leaf (value: -0.11165596703298601)
# | |  |  |  |  | Leaf (value: -0.2748954865791138)
# | | x (split: 1.9047619047619047), output value: -0.831386696278657
# | |  | x (split: 1.8596491228070176), output value: -1.3327733597471298
# | |  |  | x (split: 1.6842105263157894), output value: -1.4691668356443341
# | |  |  |  | x (split: 1.6741854636591478), output value: -0.7170439449143571
# | |  |  |  |  | Leaf (value: -0.5964064015089233)
# | |  |  |  |  | Leaf (value: -1.0789565751306587)
# | |  |  |  | x (split: 1.7393483709273183), output value: -1.576612962891474
# | |  |  |  |  | x (split: 1.7142857142857142), output value: -1.3318335042205556
# | |  |  |  |  |  | Leaf (value: -1.4171974029198664)
# | |  |  |  |  |  | Leaf (value: -1.280615165000969)
# | |  |  |  |  | x (split: 1.8395989974937343), output value: -1.674524746359841
# | |  |  |  |  |  | Leaf (value: -1.7684390232894789)
# | |  |  |  |  |  | Leaf (value: -1.2988676386412896)
# | |  |  | x (split: 1.894736842105263), output value: -0.7092603270741945
# | |  |  |  | x (split: 1.8897243107769421), output value: -0.6699232519506767
# | |  |  |  |  | x (split: 1.8796992481203008), output value: -0.7131487175684019
# | |  |  |  |  |  | Leaf (value: -0.7150680739279188)
# | |  |  |  |  |  | Leaf (value: -0.7073906484898511)
# | |  |  |  |  | Leaf (value: -0.4970213894797765)
# | |  |  |  | Leaf (value: -0.8076030148829887)
# | |  | x (split: 1.969924812030075), output value: 0.4722186287393721
# | |  |  | x (split: 1.9197994987468672), output value: 0.21033896899910737
# | |  |  |  | Leaf (value: -0.18254082967098503)
# | |  |  |  | x (split: 1.9398496240601504), output value: 0.378716025572004
# | |  |  |  |  | Leaf (value: 0.31215116233908)
# | |  |  |  |  | x (split: 1.9598997493734336), output value: 0.42863967299669703
# | |  |  |  |  |  | Leaf (value: 0.4060218899051479)
# | |  |  |  |  |  | Leaf (value: 0.4964930222713442)
# | |  |  | x (split: 1.9899749373433582), output value: 0.9959779482199018
# | |  |  |  | Leaf (value: 0.9531735426592619)
# | |  |  |  | Leaf (value: 1.0601845565608614)

# %% [markdown]
# As you can see, this is smaller and simpler than the first tree we saw. Let's see how this model performs on both the training test datasets.

# %%
fig = plt.figure(figsize=(16,5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x, y, s=50, facecolors='none', edgecolors='#94a3b8', label="original data")

# Using training data
ax.scatter(train.inputs, dt.predict(train.inputs), color='#0ea5e9', label="predicted-train")

# Using testing data
ax.scatter(test.inputs, dt.predict(test.inputs), color='#f43f5e', label="predicted-test")

ax.set_xlabel('x')
ax.set_ylabel('y')
plt.legend()

# %% [markdown]
# which gives us what we want without risking overfitting.

# %% [markdown]
# ## CHALLENGE
#
# Think of another mathematical continuous function, use it to generate data, and split the data into training and test datasets. Create a regression tree model and plot how this model works on both training and testing data. Try different `max_depth` values and plot the learning curves (max_depth vs errors).

# %%
# TODO
ch_N = 500

ch_x = np.linspace(0, 3, ch_N)

ch_y = (math.e ** (2 * ch_x)) + (math.e ** (-3 * np.sin(ch_x))) + np.random.randn(ch_N) * .5 
#e^(2*x) + e^(-3 * sin(x)) 

fig = plt.figure(figsize=(16,5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(x, y, s=50, facecolors='none', edgecolors='#94a3b8')
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
new_ds = my.DataSet(pd.DataFrame({'x': ch_x, 'y': ch_y}), y=True)

ch_train, ch_test = new_ds.train_test_split(test_portion=.25, shuffle=True)
ch_dt = DecisionTreeRegressor(ch_train)

ch_dt.print_tree()
# Out:
# |x (split: 2.4529058116232463), output value: 68.64157401956777
# | | x (split: 1.9358717434869739), output value: 27.548275961484652
# | |  | x (split: 1.4729458917835672), output value: 13.090940746559255
# | |  |  | x (split: 1.0400801603206413), output value: 6.428364329831892
# | |  |  |  | x (split: 0.7695390781563126), output value: 3.53501720687186
# | |  |  |  |  | x (split: 0.5831663326653307), output value: 2.79758444715647
# | |  |  |  |  |  | x (split: 0.3787575150300601), output value: 2.3961461498347076
# | |  |  |  |  |  |  | x (split: 0.03006012024048096), output value: 2.089974438871385
# | |  |  |  |  |  |  |  | x (split: 0.02404809619238477), output value: 2.3309858625504205
# | |  |  |  |  |  |  |  |  | x (split: 0.012024048096192385), output value: 2.15306856626692
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 2.186510537966057)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 2.0527426511695057)
# | |  |  |  |  |  |  |  |  | Leaf (value: 3.0426550476844234)
# | |  |  |  |  |  |  |  | x (split: 0.156312625250501), output value: 2.0612826027191185
# | |  |  |  |  |  |  |  |  | x (split: 0.12625250501002003), output value: 1.9086187846297695
# | |  |  |  |  |  |  |  |  |  | x (split: 0.11422845691382766), output value: 2.060166493268208
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.07214428857715431), output value: 1.998809965370449
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.06012024048096192), output value: 2.1030574728593514
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.9196243447239325)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.3782071650624803)
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.09619238476953908), output value: 1.8685005810093203
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.7835348978346863)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.1233976305332214)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.612375244348039)
# | |  |  |  |  |  |  |  |  |  | x (split: 0.15030060120240482), output value: 1.5297495130336745
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.683161571912328)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.0695133363977134)
# | |  |  |  |  |  |  |  |  | x (split: 0.3066132264529058), output value: 2.137614511763792
# | |  |  |  |  |  |  |  |  |  | x (split: 0.24048096192384769), output value: 2.206791228521971
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.18036072144288576), output value: 2.065756393821619
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.3838505522801383)
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.20440881763527055), output value: 1.9464710843996738
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.7208999386950599)
# | |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.22244488977955912), output value: 2.081813771822442
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.0449801302788218)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.137064234137873)
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.27655310621242485), output value: 2.3791671376001795
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.26452905811623245), output value: 2.5475245193026934
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.588701438960655)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.485759139815751)
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.29458917835671344), output value: 2.168720410472038
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.9833263206315668)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.724902679993452)
# | |  |  |  |  |  |  |  |  |  | x (split: 0.3486973947895792), output value: 1.964672719868345
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.3246492985971944), output value: 1.571345725625931
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.5408532705226543)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 1.6628230909357609)
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.3667334669338677), output value: 2.357999714110759
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.4368563475848473)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.1214298136884944)
# | |  |  |  |  |  |  | x (split: 0.5350701402805611), output value: 2.949610396576099
# | |  |  |  |  |  |  |  | x (split: 0.42084168336673344), output value: 3.041976683479036
# | |  |  |  |  |  |  |  |  | x (split: 0.4028056112224449), output value: 3.273650551816657
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 3.168518753395525)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 3.4313482494483565)
# | |  |  |  |  |  |  |  |  | x (split: 0.45691382765531063), output value: 2.969578599623529
# | |  |  |  |  |  |  |  |  |  | x (split: 0.45090180360721444), output value: 2.456947308676921
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.5302457125949336)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.237052096922883)
# | |  |  |  |  |  |  |  |  |  | x (split: 0.4749498997995992), output value: 3.140455696605732
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 3.3585813818680332)
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.5050100200400801), output value: 3.0677471348516314
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.49899799599198397), output value: 2.8931541635078872
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.972273124461639)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.65579728064663)
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.5290581162324649), output value: 3.207421511926628
# | |  |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.5230460921843687), output value: 3.277813176895329
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 3.2598826827008636)
# | |  |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 3.3316046594787267)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 2.9258548520518213)
# | |  |  |  |  |  |  |  | x (split: 0.5771543086172345), output value: 2.561671991583766
# | |  |  |  |  |  |  |  |  | x (split: 0.5651302605210421), output value: 2.6783817869301676
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 2.5133228731702997)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 3.1735585282097714)
# | |  |  |  |  |  |  |  |  | Leaf (value: 2.0948328101981586)
# | |  |  |  |  |  | x (split: 0.6372745490981964), output value: 3.969784275336017
# | |  |  |  |  |  |  | x (split: 0.6012024048096193), output value: 3.559975414174029
# | |  |  |  |  |  |  |  | Leaf (value: 3.6678105522240547)
# | |  |  |  |  |  |  |  | x (split: 0.625250501002004), output value: 3.4952743313440138
# | |  |  |  |  |  |  |  |  | Leaf (value: 3.438547627459917)
# | |  |  |  |  |  |  |  |  | Leaf (value: 3.5803643871701576)
# | |  |  |  |  |  |  | x (split: 0.6733466933867736), output value: 4.162635504118129
# | |  |  |  |  |  |  |  | x (split: 0.6613226452905812), output value: 4.007684547954505
# | |  |  |  |  |  |  |  |  | Leaf (value: 3.991098963133277)
# | |  |  |  |  |  |  |  |  | Leaf (value: 4.032562925186346)
# | |  |  |  |  |  |  |  | x (split: 0.6913827655310621), output value: 4.227198402519639
# | |  |  |  |  |  |  |  |  | Leaf (value: 4.448472768887217)
# | |  |  |  |  |  |  |  |  | x (split: 0.7575150300601202), output value: 4.153440280397113
# | |  |  |  |  |  |  |  |  |  | x (split: 0.7394789579158316), output value: 4.081365829268942
# | |  |  |  |  |  |  |  |  |  |  | x (split: 0.7334669338677354), output value: 4.180190769622042
# | |  |  |  |  |  |  |  |  |  |  |  | x (split: 0.721442885771543), output value: 4.099995709432166
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 4.100094974590037)
# | |  |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 4.099697913958556)
# | |  |  |  |  |  |  |  |  |  |  |  | Leaf (value: 4.500971010381547)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 3.834303478386193)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 4.4057008593457105)
# | |  |  |  |  | x (split: 0.937875751503006), output value: 6.3145714550298715
# | |  |  |  |  |  | x (split: 0.8717434869739479), output value: 5.7433450687200995
# | |  |  |  |  |  |  | x (split: 0.8176352705410822), output value: 5.402154429542262
# | |  |  |  |  |  |  |  | Leaf (value: 5.07349502161749)
# | |  |  |  |  |  |  |  | x (split: 0.8416833667334669), output value: 5.543008461510021
# | |  |  |  |  |  |  |  |  | Leaf (value: 5.64313259224632)
# | |  |  |  |  |  |  |  |  | x (split: 0.8657314629258517), output value: 5.467915363457799
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 5.466134461724612)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 5.473258068657355)
# | |  |  |  |  |  |  | x (split: 0.9198396793587175), output value: 6.311996134016496
# | |  |  |  |  |  |  |  | x (split: 0.9078156312625251), output value: 6.380527816061473
# | |  |  |  |  |  |  |  |  | x (split: 0.9018036072144289), output value: 6.3164353110275675
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 6.441510893531674)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 5.94120856351525)
# | |  |  |  |  |  |  |  |  | Leaf (value: 6.636897836197095)
# | |  |  |  |  |  |  |  | Leaf (value: 5.969337723791614)
# | |  |  |  |  |  | x (split: 0.9859719438877755), output value: 7.2285336731255025
# | |  |  |  |  |  |  | x (split: 0.9739478957915831), output value: 7.316253416123691
# | |  |  |  |  |  |  |  | x (split: 0.9679358717434869), output value: 7.170528908819831
# | |  |  |  |  |  |  |  |  | Leaf (value: 7.162324394541002)
# | |  |  |  |  |  |  |  |  | Leaf (value: 7.19514245165632)
# | |  |  |  |  |  |  |  | Leaf (value: 7.899151445339127)
# | |  |  |  |  |  |  | x (split: 1.0160320641282565), output value: 7.140813930127315
# | |  |  |  |  |  |  |  | Leaf (value: 7.082121080003289)
# | |  |  |  |  |  |  |  | Leaf (value: 7.2288532053133565)
# | |  |  |  | x (split: 1.2865731462925851), output value: 12.835061530671956
# | |  |  |  |  | x (split: 1.1903807615230462), output value: 10.659961044571709
# | |  |  |  |  |  | x (split: 1.1182364729458918), output value: 9.746488556865325
# | |  |  |  |  |  |  | x (split: 1.0821643286573146), output value: 8.935713578883048
# | |  |  |  |  |  |  |  | x (split: 1.0701402805611222), output value: 8.670172991102413
# | |  |  |  |  |  |  |  |  | Leaf (value: 8.674106679586098)
# | |  |  |  |  |  |  |  |  | Leaf (value: 8.664272458376885)
# | |  |  |  |  |  |  |  | Leaf (value: 9.378281225184105)
# | |  |  |  |  |  |  | x (split: 1.154308617234469), output value: 10.28700520885351
# | |  |  |  |  |  |  |  | x (split: 1.1422845691382766), output value: 10.012108121835103
# | |  |  |  |  |  |  |  |  | x (split: 1.1362725450901803), output value: 10.105666858180983
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 10.126844807681229)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 10.04213300968025)
# | |  |  |  |  |  |  |  |  | Leaf (value: 9.824990649143345)
# | |  |  |  |  |  |  |  | x (split: 1.1723446893787575), output value: 10.561902295871914
# | |  |  |  |  |  |  |  |  | Leaf (value: 10.508136785731773)
# | |  |  |  |  |  |  |  |  | Leaf (value: 10.615667806012054)
# | |  |  |  |  |  | x (split: 1.250501002004008), output value: 12.065303333350764
# | |  |  |  |  |  |  | x (split: 1.2384769539078155), output value: 11.610980900455461
# | |  |  |  |  |  |  |  | x (split: 1.2324649298597194), output value: 11.436759124850926
# | |  |  |  |  |  |  |  |  | x (split: 1.2264529058116231), output value: 11.398241131293593
# | |  |  |  |  |  |  |  |  |  | x (split: 1.2084168336673347), output value: 11.442331012012772
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 11.344812075493962)
# | |  |  |  |  |  |  |  |  |  |  | Leaf (value: 11.588609416790991)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 11.177791727697691)
# | |  |  |  |  |  |  |  |  | Leaf (value: 11.66786708619493)
# | |  |  |  |  |  |  |  | Leaf (value: 12.22075711507133)
# | |  |  |  |  |  |  | x (split: 1.280561122244489), output value: 13.0875288073652
# | |  |  |  |  |  |  |  | Leaf (value: 13.058285432115502)
# | |  |  |  |  |  |  |  | Leaf (value: 13.175258933114295)
# | |  |  |  |  | x (split: 1.3887775551102204), output value: 15.95585788029405
# | |  |  |  |  |  | x (split: 1.3286573146292584), output value: 14.632253767402421
# | |  |  |  |  |  |  | x (split: 1.3166332665330662), output value: 13.838663645650731
# | |  |  |  |  |  |  |  | x (split: 1.31062124248497), output value: 13.634737028877055
# | |  |  |  |  |  |  |  |  | Leaf (value: 13.821854723553152)
# | |  |  |  |  |  |  |  |  | Leaf (value: 13.073383944848763)
# | |  |  |  |  |  |  |  | Leaf (value: 14.246516879198087)
# | |  |  |  |  |  |  | x (split: 1.370741482965932), output value: 15.227446358716193
# | |  |  |  |  |  |  |  | x (split: 1.3647294589178356), output value: 14.954599444629384
# | |  |  |  |  |  |  |  |  | x (split: 1.3527054108216432), output value: 14.909176975524737
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 15.019296702375946)
# | |  |  |  |  |  |  |  |  |  | Leaf (value: 14.578817794971108)
# | |  |  |  |  |  |  |  |  | Leaf (value: 15.136289321047965)
# | |  |  |  |  |  |  |  | Leaf (value: 15.68219121552754)
# | |  |  |  |  |  | x (split: 1.4488977955911824), output value: 18.014797611458803
# | |  |  |  |  |  |  | x (split: 1.442885771543086), output value: 17.226533969570852
# | |  |  |  |  |  |  |  | x (split: 1.4308617234468937), output value: 17.099920837703156
# | |  |  |  |  |  |  |  |  | Leaf (value: 17.098025441404122)
# | |  |  |  |  |  |  |  |  | Leaf (value: 17.10560702660025)
# | |  |  |  |  |  |  |  | Leaf (value: 17.73298649704164)
# | |  |  |  |  |  |  | x (split: 1.4669338677354709), output value: 19.000127163818735
# | |  |  |  |  |  |  |  | Leaf (value: 19.08432453894557)
# | |  |  |  |  |  |  |  | Leaf (value: 18.747535038438233)
# | |  |  | x (split: 1.749498997995992), output value: 32.433904537058055
# | |  |  |  | x (split: 1.629258517034068), output value: 25.777902683845742
# | |  |  |  |  | x (split: 1.56312625250501), output value: 22.850285580510437
# | |  |  |  |  |  | x (split: 1.5150300601202404), output value: 21.221096137565972
# | |  |  |  |  |  |  | x (split: 1.503006012024048), output value: 20.435688859728124
# | |  |  |  |  |  |  |  | x (split: 1.496993987975952), output value: 20.278869116031476
# | |  |  |  |  |  |  |  |  | Leaf (value: 20.355020849674442)
# | |  |  |  |  |  |  |  |  | Leaf (value: 20.050413915102585)
# | |  |  |  |  |  |  |  | Leaf (value: 21.062967834514723)
# | |  |  |  |  |  |  | x (split: 1.5390781563126252), output value: 21.87560220243084
# | |  |  |  |  |  |  |  | Leaf (value: 21.715365324039883)
# | |  |  |  |  |  |  |  | Leaf (value: 22.035839080821802)
# | |  |  |  |  |  | x (split: 1.6112224448897796), output value: 24.841517121887
# | |  |  |  |  |  |  | x (split: 1.593186372745491), output value: 24.429578240058515
# | |  |  |  |  |  |  |  | Leaf (value: 24.022972145842107)
# | |  |  |  |  |  |  |  | Leaf (value: 24.836184334274915)
# | |  |  |  |  |  |  | Leaf (value: 25.665394885543975)
# | |  |  |  |  | x (split: 1.6953907815631262), output value: 29.68139215495949
# | |  |  |  |  |  | x (split: 1.659318637274549), output value: 27.96258363292025
# | |  |  |  |  |  |  | x (split: 1.653306613226453), output value: 27.298894983358252
# | |  |  |  |  |  |  |  | Leaf (value: 27.30767742039659)
# | |  |  |  |  |  |  |  | Leaf (value: 27.272547672243235)
# | |  |  |  |  |  |  | x (split: 1.68937875751503), output value: 28.626272282482244
# | |  |  |  |  |  |  |  | Leaf (value: 28.55289980904031)
# | |  |  |  |  |  |  |  | Leaf (value: 28.846389702808064)
# | |  |  |  |  |  | x (split: 1.7254509018036073), output value: 31.64574475157577
# | |  |  |  |  |  |  | x (split: 1.719438877755511), output value: 31.069891340293935
# | |  |  |  |  |  |  |  | Leaf (value: 31.048679473008864)
# | |  |  |  |  |  |  |  | Leaf (value: 31.133526942149146)
# | |  |  |  |  |  |  | Leaf (value: 32.41354929995155)
# | |  |  |  | x (split: 1.845691382765531), output value: 41.06205508751846
# | |  |  |  |  | x (split: 1.7975951903807614), output value: 37.20797983676895
# | |  |  |  |  |  | x (split: 1.779559118236473), output value: 35.57476552716806
# | |  |  |  |  |  |  | Leaf (value: 34.93494196188761)
# | |  |  |  |  |  |  | Leaf (value: 36.214589092448506)
# | |  |  |  |  |  | x (split: 1.8276553106212425), output value: 38.607877816426864
# | |  |  |  |  |  |  | x (split: 1.8216432865731462), output value: 38.13403678268031
# | |  |  |  |  |  |  |  | Leaf (value: 38.084051931003465)
# | |  |  |  |  |  |  |  | Leaf (value: 38.28399133771085)
# | |  |  |  |  |  |  | Leaf (value: 39.23966586142226)
# | |  |  |  |  | x (split: 1.8937875751503006), output value: 44.640839248928714
# | |  |  |  |  |  | x (split: 1.8697394789579158), output value: 42.99110369089407
# | |  |  |  |  |  |  | Leaf (value: 41.781533476186006)
# | |  |  |  |  |  |  | x (split: 1.8877755511022043), output value: 43.898281351925114
# | |  |  |  |  |  |  |  | Leaf (value: 43.699303823752246)
# | |  |  |  |  |  |  |  | Leaf (value: 44.49521393644373)
# | |  |  |  |  |  | x (split: 1.911823647294589), output value: 46.29057480696336
# | |  |  |  |  |  |  | Leaf (value: 45.23615894556957)
# | |  |  |  |  |  |  | x (split: 1.9298597194388778), output value: 47.08138670300872
# | |  |  |  |  |  |  |  | Leaf (value: 46.93004231957152)
# | |  |  |  |  |  |  |  | Leaf (value: 47.535419853320334)
# | |  | x (split: 2.2364729458917836), output value: 83.97851986490315
# | |  |  | x (split: 2.092184368737475), output value: 66.52755863262068
# | |  |  |  | x (split: 2.0080160320641283), output value: 57.243451877265954
# | |  |  |  |  | x (split: 1.9599198396793587), output value: 51.83403809795268
# | |  |  |  |  |  | Leaf (value: 50.08428724720293)
# | |  |  |  |  |  | x (split: 1.9839679358717435), output value: 52.70891352332754
# | |  |  |  |  |  |  | x (split: 1.9779559118236474), output value: 52.11119405580332
# | |  |  |  |  |  |  |  | Leaf (value: 51.923117522439064)
# | |  |  |  |  |  |  |  | Leaf (value: 52.675423655896104)
# | |  |  |  |  |  |  | Leaf (value: 53.90435245837598)
# | |  |  |  |  | x (split: 2.056112224448898), output value: 61.66933587852227
# | |  |  |  |  |  | x (split: 2.038076152304609), output value: 59.83515991864417
# | |  |  |  |  |  |  | Leaf (value: 59.02088633974262)
# | |  |  |  |  |  |  | Leaf (value: 60.64943349754572)
# | |  |  |  |  |  | x (split: 2.0741482965931866), output value: 63.87034703037598
# | |  |  |  |  |  |  | Leaf (value: 62.944149760250355)
# | |  |  |  |  |  |  | Leaf (value: 65.25964293556441)
# | |  |  |  | x (split: 2.1703406813627253), output value: 76.84323280523707
# | |  |  |  |  | x (split: 2.1282565130260522), output value: 72.06249945282333
# | |  |  |  |  |  | x (split: 2.1222444889779557), output value: 68.78197792332938
# | |  |  |  |  |  |  | Leaf (value: 68.31723890150148)
# | |  |  |  |  |  |  | Leaf (value: 70.17619498881305)
# | |  |  |  |  |  | x (split: 2.152304609218437), output value: 74.24951380581929
# | |  |  |  |  |  |  | Leaf (value: 72.53028497468391)
# | |  |  |  |  |  |  | Leaf (value: 75.96874263695469)
# | |  |  |  |  | x (split: 2.218436873747495), output value: 82.81914949575425
# | |  |  |  |  |  | x (split: 2.200400801603206), output value: 81.46090477941584
# | |  |  |  |  |  |  | Leaf (value: 79.92219494175897)
# | |  |  |  |  |  |  | Leaf (value: 82.99961461707268)
# | |  |  |  |  |  | Leaf (value: 86.89388364476947)
# | |  |  | x (split: 2.3567134268537075), output value: 111.6092084826837
# | |  |  |  | x (split: 2.314629258517034), output value: 99.36611303093082
# | |  |  |  |  | x (split: 2.278557114228457), output value: 96.70752902434849
# | |  |  |  |  |  | x (split: 2.2725450901803605), output value: 93.0141456883573
# | |  |  |  |  |  |  | Leaf (value: 92.35340059417365)
# | |  |  |  |  |  |  | Leaf (value: 94.99638097090825)
# | |  |  |  |  |  | x (split: 2.2965931863727453), output value: 99.16978458167597
# | |  |  |  |  |  |  | Leaf (value: 97.70699363948768)
# | |  |  |  |  |  |  | Leaf (value: 100.63257552386426)
# | |  |  |  |  | Leaf (value: 108.22805971953852)
# | |  |  |  | x (split: 2.404809619238477), output value: 126.07832128930072
# | |  |  |  |  | x (split: 2.3927855711422845), output value: 118.48095518634094
# | |  |  |  |  |  | Leaf (value: 116.98440945410078)
# | |  |  |  |  |  | Leaf (value: 122.97059238306132)
# | |  |  |  |  | x (split: 2.4288577154308615), output value: 130.4196733481349
# | |  |  |  |  |  | Leaf (value: 126.96301943079023)
# | |  |  |  |  |  | x (split: 2.44689378757515), output value: 133.01216378614342
# | |  |  |  |  |  |  | Leaf (value: 132.42683573960912)
# | |  |  |  |  |  |  | Leaf (value: 134.76814792574626)
# | | x (split: 2.7715430861723447), output value: 244.59034316967015
# | |  | x (split: 2.6392785571142285), output value: 189.51861992997544
# | |  |  | x (split: 2.5430861723446894), output value: 163.63812511310985
# | |  |  |  | x (split: 2.501002004008016), output value: 149.5311429026428
# | |  |  |  |  | x (split: 2.476953907815631), output value: 142.61743256368692
# | |  |  |  |  |  | x (split: 2.470941883767535), output value: 139.45476714564182
# | |  |  |  |  |  |  | Leaf (value: 138.81680625167579)
# | |  |  |  |  |  |  | Leaf (value: 141.36864982753994)
# | |  |  |  |  |  | Leaf (value: 146.8343197877471)
# | |  |  |  |  | x (split: 2.5250501002004007), output value: 156.44485324159865
# | |  |  |  |  |  | x (split: 2.5190380761523046), output value: 153.74660445503773
# | |  |  |  |  |  |  | Leaf (value: 152.8875524410057)
# | |  |  |  |  |  |  | Leaf (value: 156.32376049713383)
# | |  |  |  |  |  | Leaf (value: 160.04251829034658)
# | |  |  |  | x (split: 2.591182364729459), output value: 180.09627102532139
# | |  |  |  |  | x (split: 2.567134268537074), output value: 172.1866643796963
# | |  |  |  |  |  | Leaf (value: 167.92764500576018)
# | |  |  |  |  |  | x (split: 2.585170340681363), output value: 175.38092891014844
# | |  |  |  |  |  |  | Leaf (value: 174.2599903014899)
# | |  |  |  |  |  |  | Leaf (value: 178.7437447361241)
# | |  |  |  |  | x (split: 2.627254509018036), output value: 191.16972032919654
# | |  |  |  |  |  | Leaf (value: 188.45338019839406)
# | |  |  |  |  |  | Leaf (value: 195.2442305254002)
# | |  |  | x (split: 2.723446893787575), output value: 231.57442400738205
# | |  |  |  | x (split: 2.693386773547094), output value: 219.94061958706686
# | |  |  |  |  | x (split: 2.687374749498998), output value: 211.95293601732692
# | |  |  |  |  |  | Leaf (value: 209.88260492136382)
# | |  |  |  |  |  | Leaf (value: 218.1639293052163)
# | |  |  |  |  | x (split: 2.711422845691383), output value: 226.33076644285885
# | |  |  |  |  |  | Leaf (value: 223.62668912458352)
# | |  |  |  |  |  | Leaf (value: 230.38688242027183)
# | |  |  |  | x (split: 2.74749498997996), output value: 246.53217254778724
# | |  |  |  |  | Leaf (value: 240.00189387745354)
# | |  |  |  |  | x (split: 2.7655310621242486), output value: 251.42988155053752
# | |  |  |  |  |  | Leaf (value: 249.92340720901686)
# | |  |  |  |  |  | Leaf (value: 255.9493045750995)
# | |  | x (split: 2.8977955911823647), output value: 324.34939062026245
# | |  |  | x (split: 2.8316633266533064), output value: 290.6681926621527
# | |  |  |  | x (split: 2.8076152304609217), output value: 271.5688021031651
# | |  |  |  |  | x (split: 2.7895791583166334), output value: 266.60941211788844
# | |  |  |  |  |  | Leaf (value: 261.82170399384887)
# | |  |  |  |  |  | Leaf (value: 271.39712024192795)
# | |  |  |  |  | Leaf (value: 286.44697205899524)
# | |  |  |  | x (split: 2.867735470941884), output value: 307.6454287145861
# | |  |  |  |  | x (split: 2.849699398797595), output value: 300.888655112143
# | |  |  |  |  |  | Leaf (value: 295.3151161390804)
# | |  |  |  |  |  | Leaf (value: 306.46219408520557)
# | |  |  |  |  | Leaf (value: 321.15897591947237)
# | |  |  | x (split: 2.9398797595190382), output value: 372.064421060918
# | |  |  |  | x (split: 2.9218436873747495), output value: 346.626315420686
# | |  |  |  |  | Leaf (value: 339.9020947607512)
# | |  |  |  |  | Leaf (value: 356.7126464105882)
# | |  |  |  | x (split: 2.9819639278557113), output value: 390.2344965182266
# | |  |  |  |  | x (split: 2.975951903807615), output value: 383.05717353008754
# | |  |  |  |  |  | Leaf (value: 380.8446779587962)
# | |  |  |  |  |  | Leaf (value: 389.69466024396144)
# | |  |  |  |  | Leaf (value: 399.80426050241203)

# %%
depths = range(1,26)
ch_train_errors = []
ch_test_errors = []
for d in depths:
    ch_dt = DecisionTreeRegressor(ch_train, max_depth=d)
    ch_train_errors.append(l2_loss(ch_train.y.flatten(), ch_dt.predict(ch_train.inputs)))
    ch_test_errors.append(l2_loss(ch_test.y.flatten(), ch_dt.predict(ch_test.inputs)))
    
# Plotting the learning curves
fig = plt.figure(figsize=(16,5))
ax = fig.add_subplot(1, 1, 1)
ax.plot(depths, ch_train_errors, label="Training") 
ax.plot(depths, ch_test_errors, label="Testing") 
ax.set_xticks(np.arange(1, 26, 1))
ax.set_xlabel('max depth')
ax.set_ylabel('L2 loss')
plt.legend()

# %%
ch_dt = DecisionTreeRegressor(ch_train, max_depth=2)

fig = plt.figure(figsize=(16,5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(ch_x, ch_y, s=50, facecolors='none', edgecolors='#94a3b8', label="original data")

# Using training data
ax.scatter(ch_train.inputs, ch_dt.predict(ch_train.inputs), color='#0ea5e9', label="predicted-train")

# Using testing data
ax.scatter(ch_test.inputs, ch_dt.predict(ch_test.inputs), color='#f43f5e', label="predicted-test")

ax.set_xlabel('x')
ax.set_ylabel('y')
plt.legend()

# %%
ch_dt = DecisionTreeRegressor(ch_train, max_depth=3)

fig = plt.figure(figsize=(16,5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(ch_x, ch_y, s=50, facecolors='none', edgecolors='#94a3b8', label="original data")

# Using training data
ax.scatter(ch_train.inputs, ch_dt.predict(ch_train.inputs), color='#0ea5e9', label="predicted-train")

# Using testing data
ax.scatter(ch_test.inputs, ch_dt.predict(ch_test.inputs), color='#f43f5e', label="predicted-test")

ax.set_xlabel('x')
ax.set_ylabel('y')
plt.legend()

# %%
ch_dt = DecisionTreeRegressor(ch_train, max_depth=4)

fig = plt.figure(figsize=(16,5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(ch_x, ch_y, s=50, facecolors='none', edgecolors='#94a3b8', label="original data")

# Using training data
ax.scatter(ch_train.inputs, ch_dt.predict(ch_train.inputs), color='#0ea5e9', label="predicted-train")

# Using testing data
ax.scatter(ch_test.inputs, ch_dt.predict(ch_test.inputs), color='#f43f5e', label="predicted-test")

ax.set_xlabel('x')
ax.set_ylabel('y')
plt.legend()

# %%
ch_dt = DecisionTreeRegressor(ch_train, max_depth=5)

fig = plt.figure(figsize=(16,5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(ch_x, ch_y, s=50, facecolors='none', edgecolors='#94a3b8', label="original data")

# Using training data
ax.scatter(ch_train.inputs, ch_dt.predict(ch_train.inputs), color='#0ea5e9', label="predicted-train")

# Using testing data
ax.scatter(ch_test.inputs, ch_dt.predict(ch_test.inputs), color='#f43f5e', label="predicted-test")

ax.set_xlabel('x')
ax.set_ylabel('y')
plt.legend()
